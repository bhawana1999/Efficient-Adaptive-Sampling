# %%
# coding: utf-8
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pylab as plt
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline
import matplotlib.colors as colors
import matplotlib.cm as cm 

#GP-UCB Code
class GPUCB(object):

  def __init__(self, meshgrid, environment, beta=100.):
    '''
    beta (optional): Hyper-parameter to tune the exploration-exploitation
    balance. If beta is large, it emphasizes the variance of the unexplored
    solution solution (i.e. larger curiosity)
    '''
    self.meshgrid = np.array(meshgrid)
    self.environment = environment
    self.beta = beta

    self.X_grid = self.meshgrid.reshape(self.meshgrid.shape[0], -1).T
    self.mu = np.array([0. for _ in range(self.X_grid.shape[0])])
    self.sigma = np.array([0.5 for _ in range(self.X_grid.shape[0])])
    self.X = []
    self.T = []
    self.parameter = 1
    self.sp = 0
    
  def get_y(self, P, Q, x):
    value = (x - P[0])*(Q[1] - P[1])/(Q[0]-P[0]) + P[1]
    return value


  def get_x(self, P, Q, y):
    value = (y - P[1])*(Q[0] - P[0])/(Q[1]-P[1]) + P[0]
    return value
    
        
  def argmax_ucb(self):
    return np.argmax(self.mu + self.sigma * np.sqrt(self.beta))

  def findloc(self,arr, e):
        k=0
        for i in arr:
            #print i,e
            if i[0]== e[0] and i[1]==e[1]:
                return k
            k+=1
        return -1
                

  def variance_of_the_path(self, P, Q):
        var = 0
        
        if (abs(P[0]-Q[0]) >= abs(P[1]-Q[1])):
            #call function that gives y on passing x

            if P[0] < Q[0]:
                i = P[0]
                while (i + 0.25/self.parameter < Q[0]):
                    i += 0.25/self.parameter
                    j = self.get_y(P, Q, i)
                    var+=self.sigma[self.findloc(self.X_grid,[i,j])]
                    #print "Mid-way Next Sampling Location is  [",i,",",j,"]"
                    #self.sample([i, j])
                    #gp = GaussianProcessRegressor()
                    #gp.fit(self.X, self.T)
                    #self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
                
            else:
                i = Q[0]
                while (i + 0.25/self.parameter < P[0]):
                    i += 0.25/self.parameter
                    j = self.get_y(P, Q, i)
                    
                    var+=self.sigma[self.findloc(self.X_grid,[i,j])]
                    
                    #print "Mid-way Next Sampling Location is  [",i,",",j,"]"
                    #self.sample([i, j])
                    #gp = GaussianProcessRegressor()
                    #gp.fit(self.X, self.T)
                    #self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
            
            
        else:
            #call function that gives x on passing y
             if P[1] < Q[1] :
                i = P[1]
                while (i + 0.25/self.parameter < Q[1]):
                    i += 0.25/self.parameter
                    j = self.get_x(P, Q, i)
                    
                    var+=self.sigma[self.findloc(self.X_grid,[i,j])]
                    #print "Mid-way Next Sampling Location is  [",j,",",i,"]"
                    #self.sample([j, i])
                    #gp = GaussianProcessRegressor()
                    #gp.fit(self.X, self.T)
                    #self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
            
             else:
                i = Q[1]
                while (i + 0.25/self.parameter < P[1]):
                    i += 0.25/self.parameter
                    j = self.get_x(P, Q, i)
                    
                    var+=self.sigma[self.findloc(self.X_grid,[i,j])]
                    #print "Mid-way Next Sampling Location is  [",j,",",i,"]"
                    #self.sample([j, i])
                    #gp = GaussianProcessRegressor()
                    #gp.fit(self.X, self.T)
                    #self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
        return var    

  def sample_along_the_way(self, P,Q):
        
        if (abs(P[0]-Q[0]) >= abs(P[1]-Q[1])):
            #call function that gives y on passing x

            if P[0] < Q[0]:
                i = P[0]
                while (i + 0.25/self.parameter < Q[0]):
                    i += 0.25/self.parameter
                    j = self.get_y(P, Q, i)
                    print "Mid-way Next Sampling Location is  [",i,",",j,"]"
                    self.sample([i, j])
                    gp = GaussianProcessRegressor()
                    gp.fit(self.X, self.T)
                    self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
                
            else:
                i = Q[0]
                while (i + 0.25/self.parameter < P[0]):
                    i += 0.25/self.parameter
                    j = self.get_y(P, Q, i)
                    print "Mid-way Next Sampling Location is  [",i,",",j,"]"
                    self.sample([i, j])
                    gp = GaussianProcessRegressor()
                    gp.fit(self.X, self.T)
                    self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
            
            
        else:
            #call function that gives x on passing y
             if P[1] < Q[1] :
                i = P[1]
                while (i + 0.25/self.parameter < Q[1]):
                    i += 0.25/self.parameter
                    j = self.get_x(P, Q, i)
                    print "Mid-way Next Sampling Location is  [",j,",",i,"]"
                    self.sample([j, i])
                    gp = GaussianProcessRegressor()
                    gp.fit(self.X, self.T)
                    self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
            
             else:
                i = Q[1]
                while (i + 0.25/self.parameter < P[1]):
                    i += 0.25/self.parameter
                    j = self.get_x(P, Q, i)
                    print "Mid-way Next Sampling Location is  [",j,",",i,"]"
                    self.sample([j, i])
                    gp = GaussianProcessRegressor()
                    gp.fit(self.X, self.T)
                    self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
                    
                

  def learn(self):
    grid_idx = self.argmax_ucb()
    
    if len(self.X) > 0 and self.parameter > 0:
        P = self.X[-1]
        Q = self.X_grid[grid_idx]
        self.sample_along_the_way(P,Q)
        #v = self.variance_of_the_path(P,Q)
        #print v
        
    print "Next Sampling Location is  ", self.X_grid[grid_idx]
    self.sp += 1
    self.sample(self.X_grid[grid_idx])
    gp = GaussianProcessRegressor()
    gp.fit(self.X, self.T)
    self.mu, self.sigma = gp.predict(self.X_grid, return_std=True)
    return self.mu

  def sample(self, x):
    t = self.environment.sample(x)
    self.X.append(x)
    self.T.append(t)

  def plot(self):
    
    fig = plt.figure(figsize=(18, 8))
    fig.suptitle("Iteration %02d" %self.sp)
    
    ax = fig.add_subplot(1, 2, 1, projection='3d')
    ax.plot_wireframe(self.meshgrid[0], self.meshgrid[1],
        self.mu.reshape(self.meshgrid[0].shape), alpha=0.5, color='g')
    ax.plot_wireframe(self.meshgrid[0], self.meshgrid[1],
        self.environment.sample(self.meshgrid), alpha=0.5, color='b')
    ax.scatter([x[0] for x in self.X], [x[1] for x in self.X], self.T, c='r',
        marker='o', alpha=1.0)
    ax1 = fig.add_subplot(1, 2, 2)
    ax1 = plt.subplot(122)
    ax1.pcolormesh(self.meshgrid[0], self.meshgrid[1],
        self.mu.reshape(self.meshgrid[0].shape))
  
    plt.savefig('fig_%02d.png' % len(self.X))

# %%
if __name__ == '__main__':
  class DummyEnvironment(object):
    def sample(self, j):
      return np.sinc(j[0])+np.sin(j[1])

  x = np.arange(-3, 3, 0.25)
  y = np.arange(-3, 3, 0.25)
  env = DummyEnvironment()
  agent = GPUCB(np.meshgrid(x, y), env)

  #Actual Field
  X, Y = np.meshgrid(x, y) 
  Z = np.sinc(X)+ np.sin(Y)
  #Z = np.sinc(X)+ np.sin(Y) + np.cos(X-Y)
  plt.pcolormesh(X,Y,Z)
  plt.title("Actual Field")

# %%
#Mapping the Field--
for i in range(10):
    #print "Sampling Location "+ str(i) + " is" 
    predicted = agent.learn()
    agent.plot()
# Out:
# Next Sampling Location is   [-3. -3.]
# /home/bhawana/.local/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Mid-way Next Sampling Location is  [ -2.75 , -2.75 ]
# Mid-way Next Sampling Location is  [ -2.5 , -2.5 ]
# Mid-way Next Sampling Location is  [ -2.25 , -2.25 ]
# Mid-way Next Sampling Location is  [ -2.0 , -2.0 ]
# Mid-way Next Sampling Location is  [ -1.75 , -1.75 ]
# Mid-way Next Sampling Location is  [ -1.5 , -1.5 ]
# Mid-way Next Sampling Location is  [ -1.25 , -1.25 ]
# Mid-way Next Sampling Location is  [ -1.0 , -1.0 ]
# Mid-way Next Sampling Location is  [ -0.75 , -0.75 ]
# Mid-way Next Sampling Location is  [ -0.5 , -0.5 ]
# Mid-way Next Sampling Location is  [ -0.25 , -0.25 ]
# Mid-way Next Sampling Location is  [ 0.0 , 0.0 ]
# Mid-way Next Sampling Location is  [ 0.25 , 0.25 ]
# Mid-way Next Sampling Location is  [ 0.5 , 0.5 ]
# Mid-way Next Sampling Location is  [ 0.75 , 0.75 ]
# Mid-way Next Sampling Location is  [ 1.0 , 1.0 ]
# Mid-way Next Sampling Location is  [ 1.25 , 1.25 ]
# Mid-way Next Sampling Location is  [ 1.5 , 1.5 ]
# Mid-way Next Sampling Location is  [ 1.75 , 1.75 ]
# /home/bhawana/.local/lib/python2.7/site-packages/sklearn/gaussian_process/gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# Mid-way Next Sampling Location is  [ 2.0 , 2.0 ]
# Mid-way Next Sampling Location is  [ 2.25 , 2.25 ]
# Mid-way Next Sampling Location is  [ 2.5 , 2.5 ]
# Next Sampling Location is   [2.75 2.75]
# Mid-way Next Sampling Location is  [ 1.8125 , -1.0 ]
# Mid-way Next Sampling Location is  [ 1.875 , -0.75 ]
# Mid-way Next Sampling Location is  [ 1.9375 , -0.5 ]
# Mid-way Next Sampling Location is  [ 2.0 , -0.25 ]
# Mid-way Next Sampling Location is  [ 2.0625 , 0.0 ]
# Mid-way Next Sampling Location is  [ 2.125 , 0.25 ]
# Mid-way Next Sampling Location is  [ 2.1875 , 0.5 ]
# Mid-way Next Sampling Location is  [ 2.25 , 0.75 ]
# Mid-way Next Sampling Location is  [ 2.3125 , 1.0 ]
# Mid-way Next Sampling Location is  [ 2.375 , 1.25 ]
# Mid-way Next Sampling Location is  [ 2.4375 , 1.5 ]
# Mid-way Next Sampling Location is  [ 2.5 , 1.75 ]
# Mid-way Next Sampling Location is  [ 2.5625 , 2.0 ]
# Mid-way Next Sampling Location is  [ 2.625 , 2.25 ]
# Mid-way Next Sampling Location is  [ 2.6875 , 2.5 ]
# Next Sampling Location is   [ 1.75 -1.25]
# Mid-way Next Sampling Location is  [ -1.0 , 1.5 ]
# Mid-way Next Sampling Location is  [ -0.75 , 1.25 ]
# Mid-way Next Sampling Location is  [ -0.5 , 1.0 ]
# Mid-way Next Sampling Location is  [ -0.25 , 0.75 ]
# Mid-way Next Sampling Location is  [ 0.0 , 0.5 ]
# Mid-way Next Sampling Location is  [ 0.25 , 0.25 ]
# Mid-way Next Sampling Location is  [ 0.5 , 0.0 ]
# Mid-way Next Sampling Location is  [ 0.75 , -0.25 ]
# Mid-way Next Sampling Location is  [ 1.0 , -0.5 ]
# Mid-way Next Sampling Location is  [ 1.25 , -0.75 ]
# Mid-way Next Sampling Location is  [ 1.5 , -1.0 ]
# Next Sampling Location is   [-1.25  1.75]
# Mid-way Next Sampling Location is  [ -2.75 , 0.6785714285714286 ]
# Mid-way Next Sampling Location is  [ -2.5 , 0.8571428571428571 ]
# Mid-way Next Sampling Location is  [ -2.25 , 1.0357142857142856 ]
# Mid-way Next Sampling Location is  [ -2.0 , 1.2142857142857144 ]
# Mid-way Next Sampling Location is  [ -1.75 , 1.3928571428571428 ]
# Mid-way Next Sampling Location is  [ -1.5 , 1.5714285714285714 ]
# Next Sampling Location is   [-3.   0.5]
# Mid-way Next Sampling Location is  [ -0.6785714285714284 , -2.75 ]
# Mid-way Next Sampling Location is  [ -0.8571428571428572 , -2.5 ]
# Mid-way Next Sampling Location is  [ -1.0357142857142858 , -2.25 ]
# Mid-way Next Sampling Location is  [ -1.2142857142857142 , -2.0 ]
# Mid-way Next Sampling Location is  [ -1.3928571428571428 , -1.75 ]
# Mid-way Next Sampling Location is  [ -1.5714285714285714 , -1.5 ]
# Mid-way Next Sampling Location is  [ -1.75 , -1.25 ]
# Mid-way Next Sampling Location is  [ -1.9285714285714286 , -1.0 ]
# Mid-way Next Sampling Location is  [ -2.107142857142857 , -0.75 ]
# Mid-way Next Sampling Location is  [ -2.2857142857142856 , -0.5 ]
# Mid-way Next Sampling Location is  [ -2.4642857142857144 , -0.25 ]
# Mid-way Next Sampling Location is  [ -2.642857142857143 , 0.0 ]
# Mid-way Next Sampling Location is  [ -2.8214285714285716 , 0.25 ]
# Next Sampling Location is   [-0.5 -3. ]
# Mid-way Next Sampling Location is  [ -0.44565217391304346 , -2.75 ]
# Mid-way Next Sampling Location is  [ -0.391304347826087 , -2.5 ]
# Mid-way Next Sampling Location is  [ -0.33695652173913043 , -2.25 ]
# Mid-way Next Sampling Location is  [ -0.28260869565217395 , -2.0 ]
# Mid-way Next Sampling Location is  [ -0.2282608695652174 , -1.75 ]
# Mid-way Next Sampling Location is  [ -0.17391304347826086 , -1.5 ]
# Mid-way Next Sampling Location is  [ -0.11956521739130432 , -1.25 ]
# Mid-way Next Sampling Location is  [ -0.06521739130434784 , -1.0 ]
# Mid-way Next Sampling Location is  [ -0.010869565217391297 , -0.75 ]
# Mid-way Next Sampling Location is  [ 0.04347826086956519 , -0.5 ]
# Mid-way Next Sampling Location is  [ 0.09782608695652173 , -0.25 ]
# Mid-way Next Sampling Location is  [ 0.15217391304347827 , 0.0 ]
# Mid-way Next Sampling Location is  [ 0.2065217391304348 , 0.25 ]
# Mid-way Next Sampling Location is  [ 0.26086956521739135 , 0.5 ]
# Mid-way Next Sampling Location is  [ 0.3152173913043478 , 0.75 ]
# Mid-way Next Sampling Location is  [ 0.3695652173913043 , 1.0 ]
# Mid-way Next Sampling Location is  [ 0.42391304347826086 , 1.25 ]
# Mid-way Next Sampling Location is  [ 0.4782608695652174 , 1.5 ]
# Mid-way Next Sampling Location is  [ 0.5326086956521738 , 1.75 ]
# Mid-way Next Sampling Location is  [ 0.5869565217391304 , 2.0 ]
# Mid-way Next Sampling Location is  [ 0.6413043478260869 , 2.25 ]
# Mid-way Next Sampling Location is  [ 0.6956521739130435 , 2.5 ]
# Next Sampling Location is   [0.75 2.75]
# Mid-way Next Sampling Location is  [ -2.75 , 2.75 ]
# Mid-way Next Sampling Location is  [ -2.5 , 2.75 ]
# Mid-way Next Sampling Location is  [ -2.25 , 2.75 ]
# Mid-way Next Sampling Location is  [ -2.0 , 2.75 ]
# Mid-way Next Sampling Location is  [ -1.75 , 2.75 ]
# Mid-way Next Sampling Location is  [ -1.5 , 2.75 ]
# Mid-way Next Sampling Location is  [ -1.25 , 2.75 ]
# Mid-way Next Sampling Location is  [ -1.0 , 2.75 ]
# Mid-way Next Sampling Location is  [ -0.75 , 2.75 ]
# Mid-way Next Sampling Location is  [ -0.5 , 2.75 ]
# Mid-way Next Sampling Location is  [ -0.25 , 2.75 ]
# Mid-way Next Sampling Location is  [ 0.0 , 2.75 ]
# Mid-way Next Sampling Location is  [ 0.25 , 2.75 ]
# Mid-way Next Sampling Location is  [ 0.5 , 2.75 ]
# Next Sampling Location is   [-3.    2.75]
# Mid-way Next Sampling Location is  [ -2.75 , 2.5 ]
# Mid-way Next Sampling Location is  [ -2.5 , 2.25 ]
# Mid-way Next Sampling Location is  [ -2.25 , 2.0 ]
# Mid-way Next Sampling Location is  [ -2.0 , 1.75 ]
# Mid-way Next Sampling Location is  [ -1.75 , 1.5 ]
# Mid-way Next Sampling Location is  [ -1.5 , 1.25 ]
# Mid-way Next Sampling Location is  [ -1.25 , 1.0 ]
# Mid-way Next Sampling Location is  [ -1.0 , 0.75 ]
# Mid-way Next Sampling Location is  [ -0.75 , 0.5 ]
# Mid-way Next Sampling Location is  [ -0.5 , 0.25 ]
# Mid-way Next Sampling Location is  [ -0.25 , 0.0 ]
# Mid-way Next Sampling Location is  [ 0.0 , -0.25 ]
# Mid-way Next Sampling Location is  [ 0.25 , -0.5 ]
# Mid-way Next Sampling Location is  [ 0.5 , -0.75 ]
# Mid-way Next Sampling Location is  [ 0.75 , -1.0 ]
# Mid-way Next Sampling Location is  [ 1.0 , -1.25 ]
# Mid-way Next Sampling Location is  [ 1.25 , -1.5 ]
# Mid-way Next Sampling Location is  [ 1.5 , -1.75 ]
# Mid-way Next Sampling Location is  [ 1.75 , -2.0 ]
# Mid-way Next Sampling Location is  [ 2.0 , -2.25 ]
# Mid-way Next Sampling Location is  [ 2.25 , -2.5 ]
# Mid-way Next Sampling Location is  [ 2.5 , -2.75 ]
# Next Sampling Location is   [ 2.75 -3.  ]
# Mid-way Next Sampling Location is  [ -2.75 , -1.565217391304348 ]
# Mid-way Next Sampling Location is  [ -2.5 , -1.6304347826086956 ]
# Mid-way Next Sampling Location is  [ -2.25 , -1.6956521739130435 ]
# Mid-way Next Sampling Location is  [ -2.0 , -1.7608695652173914 ]
# Mid-way Next Sampling Location is  [ -1.75 , -1.826086956521739 ]
# Mid-way Next Sampling Location is  [ -1.5 , -1.891304347826087 ]
# Mid-way Next Sampling Location is  [ -1.25 , -1.9565217391304348 ]
# Mid-way Next Sampling Location is  [ -1.0 , -2.0217391304347827 ]
# Mid-way Next Sampling Location is  [ -0.75 , -2.0869565217391304 ]
# Mid-way Next Sampling Location is  [ -0.5 , -2.1521739130434785 ]
# Mid-way Next Sampling Location is  [ -0.25 , -2.217391304347826 ]
# Mid-way Next Sampling Location is  [ 0.0 , -2.282608695652174 ]
# Mid-way Next Sampling Location is  [ 0.25 , -2.3478260869565215 ]
# Mid-way Next Sampling Location is  [ 0.5 , -2.4130434782608696 ]
# Mid-way Next Sampling Location is  [ 0.75 , -2.4782608695652173 ]
# Mid-way Next Sampling Location is  [ 1.0 , -2.5434782608695654 ]
# Mid-way Next Sampling Location is  [ 1.25 , -2.608695652173913 ]
# Mid-way Next Sampling Location is  [ 1.5 , -2.6739130434782608 ]
# Mid-way Next Sampling Location is  [ 1.75 , -2.739130434782609 ]
# Mid-way Next Sampling Location is  [ 2.0 , -2.8043478260869565 ]
# Mid-way Next Sampling Location is  [ 2.25 , -2.869565217391304 ]
# Mid-way Next Sampling Location is  [ 2.5 , -2.9347826086956523 ]
# Next Sampling Location is   [-3.  -1.5]

# %%
print Z.shape
print "ok",predicted.shape
k=0
error = []
for i in Z:
    for j in i:
        error.append(abs(j-predicted[k]))
        k+=1
        
MappingError = sum(error)
MappingError
# Out:
# (24, 24)
# ok (576,)
# 9.121186912368184
